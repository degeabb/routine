# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
df = pd.read_excel('G:/all_deal_2010-2020.xlsx')

# %%
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)

# %%
df.tail()
# Out:
#        Deal ID      Deal Type Announcement Date Closing Date Deal Status  \
# 87409   146313  VC Investment        12/31/2020   12/31/2020      Closed
# 87410   136437  VC Investment        12/31/2020   12/31/2020      Closed
# 87411   158675  VC Investment        12/31/2020   12/31/2020      Closed
# 87412   157372  VC Investment        12/31/2020   12/31/2020      Closed
# 87413   133581  VC Investment        12/31/2020   12/31/2020      Closed
#
#       Acquisition Technique  Transaction Amount (US$m.) Transaction Currency  \
# 87409     Private Placement                       20.00            US Dollar
# 87410     Private Placement                       22.92  China Yuan Renminbi
# 87411     Private Placement                       38.67         Japanese Yen
# 87412     Private Placement                      100.00            US Dollar
# 87413     Private Placement                      100.00            US Dollar
#
#        Transaction Amount (Transaction Currency)  Stake (%)  \
# ...

# %%
df['Announcement Date'] = pd.to_datetime(df['Announcement Date'])

# %%
df['Investee/Target - Description'] = df['Investee/Target - Description'].str.lower()

# %%
# df['Transaction Date'].fillna(value=df['Closing Date'], inplace=True)

# %%
drone_df = df[df['Investee/Target - Description'].str.contains('drone', 'drones', na=False)]

# %%
drone_df['Announcement Date'] = pd.to_datetime(drone_df['Announcement Date'])
# Out:
# <ipython-input-91-3f2f04415d3e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   drone_df['Announcement Date'] = pd.to_datetime(drone_df['Announcement Date'])

# %%
drone_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 124 entries, 9190 to 86986
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Deal ID                                    124 non-null    int64
#  1   Deal Type                                  124 non-null    object
#  2   Announcement Date                          124 non-null    datetime64[ns]
#  3   Closing Date                               115 non-null    object
#  4   Deal Status                                124 non-null    object
#  5   Acquisition Technique                      124 non-null    object
#  6   Transaction Amount (US$m.)                 71 non-null     float64
#  7   Transaction Currency                       124 non-null    object
#  8   Transaction Amount (Transaction Currency)  71 non-null     float64
#  9   Stake (%)                                  9 non-null      float64
# ...

# %%
group_df= pd.DataFrame()

# %%
group_df= drone_df.groupby(pd.Grouper(key="Announcement Date", freq="1Y")).count()

# %%
group_df
# Out:
#                    Deal ID  Deal Type  Closing Date  Deal Status  \
# Announcement Date
# 2013-12-31               1          1             1            1
# 2014-12-31               4          4             4            4
# 2015-12-31              11         11            11           11
# 2016-12-31              20         20            18           20
# 2017-12-31              18         18            18           18
# 2018-12-31              19         19            16           19
# 2019-12-31              24         24            22           24
# 2020-12-31              27         27            25           27
#
#                    Acquisition Technique  Transaction Amount (US$m.)  \
# Announcement Date
# 2013-12-31                             1                           0
# 2014-12-31                             4                           2
# 2015-12-31                            11                           7
# ...

# %%
group_df2= pd.DataFrame()

# %%
group_df2= drone_df.groupby(pd.Grouper(key="Announcement Date", freq="1Y")).sum()

# %%
group_df2
# Out:
#                    Deal ID  Transaction Amount (US$m.)  \
# Announcement Date
# 2013-12-31          110974                        0.00
# 2014-12-31          425814                       30.00
# 2015-12-31         1267794                      182.16
# 2016-12-31         2494181                       62.93
# 2017-12-31         2416479                       50.01
# 2018-12-31         2555770                       78.15
# 2019-12-31         3411311                       92.71
# 2020-12-31         3867456                      396.74
#
#                    Transaction Amount (Transaction Currency)  Stake (%)  \
# Announcement Date
# 2013-12-31                                              0.00       0.00
# 2014-12-31                                             30.00      50.00
# 2015-12-31                                            978.05      20.94
# 2016-12-31                                           1038.90      59.00
# ...

# %%
group_df.to_excel('G:/group1.xlsx')

# %%
group_df2.to_excel('G:/group2.xlsx')

# %%
drone_df.to_excel('G:/dronedf.xlsx')

# %%
vr_df = df[df['Investee/Target - Description'].str.contains('virtual reality', na=False)]

# %%
ar_df = df[df['Investee/Target - Description'].str.contains('augmented reality', na=False)]

# %%
vr_df.to_excel('G:/vrdf.xlsx')

# %%
ar_df.to_excel('G:/ardf.xlsx')

# %%
vr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 155 entries, 9871 to 86912
# Data columns (total 28 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Deal ID                                    155 non-null    int64
#  1   Deal Type                                  155 non-null    object
#  2   Announcement Date                          155 non-null    datetime64[ns]
#  3   Closing Date                               148 non-null    object
#  4   Deal Status                                155 non-null    object
#  5   Acquisition Technique                      155 non-null    object
#  6   Transaction Amount (US$m.)                 93 non-null     float64
#  7   Transaction Currency                       155 non-null    object
#  8   Transaction Amount (Transaction Currency)  93 non-null     float64
#  9   Stake (%)                                  20 non-null     float64
# ...

# %% [markdown]
# ## Find all investments made from JAFCO

# %%
jafco = df[df['Investor/Acquiror'].str.contains('JAFCO', na=False)]

# %%
jafco
# Out:
#        Deal ID      Deal Type Announcement Date         Closing Date  \
# 42892    83070  PE Investment        2011-09-30           09/30/2011
# 43157    86373  PE Investment        2012-08-03           03/14/2012
# 43219    36051  PE Investment        2012-04-16           05/15/2012
# 44382   140510  PE Investment        2014-04-28           04/28/2014
# 45579   115892  PE Investment        2016-01-02  2016-01-02 00:00:00
# ...        ...            ...               ...                  ...
# 86473   155401  VC Investment        2020-07-10  2020-07-10 00:00:00
# 86808   117781  VC Investment        2020-03-11  2020-03-11 00:00:00
# 87226   138951  VC Investment        2020-10-12  2020-10-12 00:00:00
# 87250   129378  VC Investment        2020-12-14           12/14/2020
# 87308   157167  VC Investment        2020-12-21           12/21/2020
#
#       Deal Status Acquisition Technique  Transaction Amount (US$m.)  \
# 42892      Closed     Private Placement                       45.28
# ...
